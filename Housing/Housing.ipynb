# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

for dirname , _ ,filenames in os.walk('Housing/'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# Housing/sample_submission.csv
# Housing/test.csv
# Housing/train.csv

# %%
df = pd.read_csv('Housing/train.csv')
df.sample(15)
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 8524     Dealer                   0     0        2       BHK  1050.071847
# 20546     Owner                   0     0        3       BHK  1500.110302
# 17377    Dealer                   1     0        3       BHK   833.017796
# 26799    Dealer                   0     1        2       BHK  1100.025582
# 7289     Dealer                   0     0        3       BHK  1984.126984
# 19698    Dealer                   1     1        3       BHK  1108.297624
# 14035    Dealer                   0     0        4       BHK  2650.059626
# 25393    Dealer                   0     0        3       BHK  1800.041144
# 21920    Dealer                   0     0        3       BHK  1499.993478
# 16545    Dealer                   0     0        3       BHK  1350.135014
# 25998     Owner                   0     0        5       BHK  2150.294251
# 25816     Owner                   0     0        3       BHK  1565.133638
# 15947    Dealer                   0     0        3       BHK  1076.445904
# 24569     Owner                   0     0        2       BHK   625.000000
# 13285     Owner                   0     0        1       BHK  1000.000000
#
#        READY_TO_MOVE  RESALE  \
# 8524               1       1
# 20546              1       1
# 17377              0       1
# 26799              1       1
# 7289               1       1
# 19698              0       1
# 14035              1       1
# 25393              1       1
# 21920              1       1
# 16545              1       1
# 25998              1       1
# 25816              1       1
# 15947              1       1
# 24569              1       1
# 13285              1       1
#
#                                                  ADDRESS  LONGITUDE  \
# 8524                              Sector 5 Ulwe,Lalitpur  22.575343
# 20546                                Avanti Vihar,Raipur  21.244392
# 17377                                  Makardaha,Kolkata  22.620000
# 26799                                         Moshi,Pune  18.669919
# 7289                                Ambalipura,Bangalore  12.915026
# 19698                               Whitefield,Bangalore  12.995893
# 14035            Hiranandani Gardens - Powai,Maharashtra  19.124896
# 25393                             Basavanapura,Bangalore  12.848285
# 21920                                Malabar Hill,Mumbai  18.951632
# 16545                                       Yerwada,Pune  18.559756
# 25998                               Seegehalli,Bangalore  12.817956
# 25816                             Vidyaratna Nagar,Udupi  23.830000
# 15947                                       Mamurdi,Pune  18.673472
# 24569                                   Mango,Jamshedpur  22.835481
# 13285  OPP - T B HOSPITAL, NR - RAMESHVAR BUS STOP,Ja...  19.048746
#
#         LATITUDE  TARGET(PRICE_IN_LACS)
# 8524   88.433715                   95.0
# 20546  81.671075                   68.0
# 17377  88.240000                   22.0
# 26799  73.853723                   43.0
# 7289   77.668562                  150.0
# 19698  77.761394                   56.9
# 14035  72.893503                 1000.0
# 25393  77.591765                   87.5
# 21920  72.798626                 1150.0
# 16545  73.882438                  120.0
# 25998  77.452539                   95.0
# 25816  78.710000                   65.0
# 15947  73.714564                   59.0
# 24569  86.221099                   16.0
# 13285  72.932337                   14.0

# %%
df.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
df.drop(["ADDRESS"], axis = 1, inplace=True)

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# 25%         1.000000      1.000000     18.452663     73.798100
# 50%         1.000000      1.000000     20.750000     77.324137
# 75%         1.000000      1.000000     26.900926     77.828740
# max         1.000000      1.000000     59.912884    152.962676
#
#        TARGET(PRICE_IN_LACS)
# count           29451.000000
# mean              142.898746
# std               656.880713
# min                 0.250000
# 25%                38.000000
# 50%                62.000000
# 75%               100.000000
# max             30000.000000

# %%
"""from pandas_profiling import ProfileReport
profile = ProfileReport(df,title='Pandas Profiling Report',explorative=True)
profile.to_widgets()"""
# Out:
# "from pandas_profiling import ProfileReport\nprofile = ProfileReport(df,title='Pandas Profiling Report',explorative=True)\nprofile.to_widgets()"

# %%
features=['POSTED_BY','UNDER_CONSTRUCTION','RERA','BHK_OR_RK','READY_TO_MOVE','RESALE']

# %%
sns.set_style('white')

for feature in features:
    plt.figure(figsize=(10,7))
    sns.barplot(x=df[feature].value_counts().index, y=df[feature].value_counts().values)

    plt.ylabel('Number of Samples')
    plt.xlabel(f'feature', style = 'normal', size = 24)

    plt.xticks(rotation = 45, size = 12)
    plt.yticks(rotation = 45, size = 12)

    plt.title(f'Distribution of {feature}',color = 'black',fontsize=15)
    plt.show()

# %%
sns.set(style='whitegrid')



for feature in features:
    plt.figure(figsize=(10, 5))
    plt.pie(df[feature].value_counts(),labels=df[feature].value_counts().index,
            autopct='%1.2f%%',colors=['#E37383','#FFC0CB'], )
    plt.title(f'Distribution of {feature}', color = 'black',fontsize = 15)
    plt.axis('equal')
    plt.show()

# %%
sns.set_style('darkgrid')
for feature in features:
    plt.figure(figsize=(10, 10))
    sns.violinplot(x = feature, y = 'TARGET(PRICE_IN_LACS)', data = df)

# %%
sns.set_style('darkgrid')
for feature in features:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x = feature, y = 'TARGET(PRICE_IN_LACS)', data = df)

# %%
plt.figure(figsize=(20,15))
sns.set_style('white')
sns.distplot(df['TARGET(PRICE_IN_LACS)'], color="#ff9999").set_title('TARGET(PRICE_IN_LACS')
# Out:
# C:\Users\shawn\anaconda3\envs\tf-gpu\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'TARGET(PRICE_IN_LACS')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))

sns.scatterplot(x=df['TARGET(PRICE_IN_LACS)'], y=df['SQUARE_FT'],
                    hue=df['UNDER_CONSTRUCTION'], 
                    palette='tab20', 
                    linewidth=0,
                    data=df)
# Out:
# <AxesSubplot:xlabel='TARGET(PRICE_IN_LACS)', ylabel='SQUARE_FT'>

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))

sns.scatterplot(x=df['TARGET(PRICE_IN_LACS)'], y=df['BHK_NO.'],
                    hue=df['UNDER_CONSTRUCTION'], 
                    palette='tab20', 
                    linewidth=0,
                    data=df)
# Out:
# <AxesSubplot:xlabel='TARGET(PRICE_IN_LACS)', ylabel='BHK_NO.'>

# %%
sns.set_style('darkgrid')
df.plot(kind='scatter',x='LONGITUDE',y='LATITUDE',alpha=0.4,c="TARGET(PRICE_IN_LACS)",cmap=plt.get_cmap("jet"),colorbar=True)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
plt.figure(figsize=(12,10)) 
sns.heatmap(df.corr(), annot=True, linewidths = 2)
plt.show()

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#        UNDER_CONSTRUCTION  RERA  BHK_NO.    SQUARE_FT  READY_TO_MOVE  RESALE  \
# 0                       0     0        2  1300.236407              1       1
# 1                       0     0        2  1275.000000              1       1
# 2                       0     0        2   933.159722              1       1
# 3                       0     1        2   929.921143              1       1
# 4                       1     0        2   999.009247              0       1
# ...                   ...   ...      ...          ...            ...     ...
# 29446                   0     0        3  2500.000000              1       1
# 29447                   0     0        2   769.230769              1       1
# 29448                   0     0        2  1022.641509              1       1
# 29449                   0     0        2   927.079009              1       1
# 29450                   0     1        2   896.774194              1       1
#
#        LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)  POSTED_BY_Dealer  \
# 0      12.969910  77.597960                   55.0                 0
# 1      12.274538  76.644605                   51.0                 1
# 2      12.778033  77.632191                   43.0                 0
# 3      28.642300  77.344500                   62.5                 0
# 4      22.592200  88.484911                   60.5                 1
# ...          ...        ...                    ...               ...
# 29446  27.140626  78.043277                   45.0                 0
# 29447  39.945409 -86.150721                   16.0                 0
# 29448  26.928785  75.828002                   27.1                 1
# 29449  12.900150  80.227910                   67.0                 0
# 29450  26.832353  75.841749                   27.8                 1
#
#        POSTED_BY_Owner  BHK_OR_RK_RK
# 0                    1             0
# 1                    0             0
# 2                    1             0
# 3                    1             0
# 4                    0             0
# ...                ...           ...
# 29446                1             0
# 29447                1             0
# 29448                0             0
# 29449                1             0
# 29450                0             0
#
# [29451 rows x 12 columns]

# %%
quantile1, quantile3= np.percentile(df['TARGET(PRICE_IN_LACS)'],[25,75])

# %%
print(quantile1,quantile3)
# Out:
# 38.0 100.0

# %%
## Find the IQR

iqr=quantile3-quantile1
print(iqr)
# Out:
# 62.0

# %%
## Find the lower bound value and the higher bound value

lower_bound_val = quantile1 -(1.5 * iqr) 
upper_bound_val = quantile3 +(1.5 * iqr)

# %%
print(lower_bound_val,upper_bound_val)
# Out:
# -55.0 193.0

# %%
  df_out = df.loc[~((df['TARGET(PRICE_IN_LACS)'] > upper_bound_val ) | (df['TARGET(PRICE_IN_LACS)'] < lower_bound_val ))]

# %%
df_out
# Out:
#        UNDER_CONSTRUCTION  RERA  BHK_NO.    SQUARE_FT  READY_TO_MOVE  RESALE  \
# 0                       0     0        2  1300.236407              1       1
# 1                       0     0        2  1275.000000              1       1
# 2                       0     0        2   933.159722              1       1
# 3                       0     1        2   929.921143              1       1
# 4                       1     0        2   999.009247              0       1
# ...                   ...   ...      ...          ...            ...     ...
# 29446                   0     0        3  2500.000000              1       1
# 29447                   0     0        2   769.230769              1       1
# 29448                   0     0        2  1022.641509              1       1
# 29449                   0     0        2   927.079009              1       1
# 29450                   0     1        2   896.774194              1       1
#
#        LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)  POSTED_BY_Dealer  \
# 0      12.969910  77.597960                   55.0                 0
# 1      12.274538  76.644605                   51.0                 1
# 2      12.778033  77.632191                   43.0                 0
# 3      28.642300  77.344500                   62.5                 0
# 4      22.592200  88.484911                   60.5                 1
# ...          ...        ...                    ...               ...
# 29446  27.140626  78.043277                   45.0                 0
# 29447  39.945409 -86.150721                   16.0                 0
# 29448  26.928785  75.828002                   27.1                 1
# 29449  12.900150  80.227910                   67.0                 0
# 29450  26.832353  75.841749                   27.8                 1
#
#        POSTED_BY_Owner  BHK_OR_RK_RK
# 0                    1             0
# 1                    0             0
# 2                    1             0
# 3                    1             0
# 4                    0             0
# ...                ...           ...
# 29446                1             0
# 29447                1             0
# 29448                0             0
# 29449                1             0
# 29450                0             0
#
# [26367 rows x 12 columns]

# %%
X=df_out.drop(columns=['TARGET(PRICE_IN_LACS)'])
y=df_out['TARGET(PRICE_IN_LACS)']

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.00410469 0.00577047 0.15249413 0.25246079 0.00779475 0.00641029
#  0.26470666 0.19636695 0.10884052 0.00078434 0.00026642]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(9).plot(kind='barh')
plt.show()

# %%
X=X.drop(columns=['POSTED_BY_Owner','RERA','UNDER_CONSTRUCTION','READY_TO_MOVE','RESALE','BHK_OR_RK_RK'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor()

n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
from sklearn.model_selection import RandomizedSearchCV
 #Randomized Search CV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()
 random_grid,scoring='neg_mean_squared_error', n_iter 
rf_random = RandomizedSearchCV(estimator = regressor, param_distributions == 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  32.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  32.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  32.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  31.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  33.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  50.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  48.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  51.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  54.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  52.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  21.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  21.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  20.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  20.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  19.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  36.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  35.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  34.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  35.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  36.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=  57.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 1.0min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 1.0min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 1.0min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=  57.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=  24.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=  23.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=  25.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=  24.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=  24.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  12.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  13.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  14.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  13.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  14.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  15.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  14.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  15.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  15.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  15.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 1.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 1.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 1.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 1.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 1.1min
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 25}

# %%
rf_random.best_score_
# Out:
# -431.7076255958535

# %%
predictions=rf_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# C:\Users\shawn\anaconda3\envs\tf-gpu\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TARGET(PRICE_IN_LACS)', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 13.057107091755533
# MSE: 408.6641320696674
# RMSE: 20.21544291054904

# %%
print('MAE:', metrics.mean_absolute_error(y_train, rf_random.predict(X_train)))
print('MSE:', metrics.mean_squared_error(y_train, rf_random.predict(X_train)))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, rf_random.predict(X_train))))
# Out:
# MAE: 5.070962631245507
# MSE: 60.419776954957435
# RMSE: 7.773015949742895

# %%
mean = np.mean(y_train)

print(f"RMSLE for predicting only 0: {round(np.sqrt(metrics.mean_squared_error(y_train, np.zeros(len(y_train)))), 5)}")
print(f"RMSLE for predicting only 1: {round(np.sqrt(metrics.mean_squared_error(y_train, np.ones(len(y_train)))), 5)}")
print(f"RMSLE for predicting the mean ({round(mean, 2)}): {round(np.sqrt(metrics.mean_squared_error(y_train, np.full(len(y_train), mean))), 5)}")
# Out:
# RMSLE for predicting only 0: 77.67016
# RMSLE for predicting only 1: 76.81861
# RMSLE for predicting the mean (66.28): 40.49664

# %%
const_rmses = dict()
for i in range(70):
    const = i*2
    rmse = round(np.sqrt(metrics.mean_squared_error(y_train, np.full(len(y_train), const))), 5)
#     print(f"RMSLE for predicting only {const}: {rmsle}")
    const_rmses[const] = rmse

xs = list(const_rmses.keys())
ys = list(const_rmses.values())

pd.DataFrame(ys, index=xs).plot(figsize=(15, 10), legend=None)
plt.scatter(min(const_rmses, key=const_rmses.get), sorted(ys)[0], color='red')
plt.title("RMSE scores for constant predictions", fontsize=18, weight='bold')
plt.xticks(fontsize=14)
plt.xlabel("Constant", fontsize=14)
plt.ylabel("RMSE", rotation=0, fontsize=14)

# %%
const_rmses = dict()
for i in range(30,37):
    const = i*2
    rmse = round(np.sqrt(metrics.mean_squared_error(y_train, np.full(len(y_train), const))), 5)
#     print(f"RMSLE for predicting only {const}: {rmsle}")
    const_rmses[const] = rmse

xs = list(const_rmses.keys())
ys = list(const_rmses.values())

pd.DataFrame(ys, index=xs).plot(figsize=(15, 10), legend=None)
plt.scatter(min(const_rmses, key=const_rmses.get), sorted(ys)[0], color='red')
plt.title("RMSE scores for constant predictions", fontsize=18, weight='bold')
plt.xticks(fontsize=14)
plt.xlabel("Constant", fontsize=14)
plt.ylabel("RMSE", rotation=0, fontsize=14);

# %% [markdown]
# its found that best rmse constant value is 66

# %%
best_const=66

# %%
print(f"RMSLE for predicting the best possible constant on our data: {round(np.sqrt(metrics.mean_squared_error(y_train, np.full(len(y_train), best_const))), 5)}\n")
# Out:
# RMSLE for predicting the best possible constant on our data: 40.49759

# %% [markdown]
# This is the optimal RMSE score that we can get with only a constant prediction and using all data available.
# We therefore call it the best 'Naive baseline'
# A model should at least perform better than this RMSE score.

# %%
test_df=df = pd.read_csv('Housing/test.csv')
test_df.drop(columns=['ADDRESS'],inplace=True)

# %%
test_df=pd.get_dummies(test_df,drop_first=True)

# %%
test_df
# Out:
#        UNDER_CONSTRUCTION  RERA  BHK_NO.     SQUARE_FT  READY_TO_MOVE  RESALE  \
# 0                       0     0        1    545.171340              1       1
# 1                       1     1        2    800.000000              0       0
# 2                       0     0        2   1257.096513              1       1
# 3                       0     0        3   1400.329489              1       1
# 4                       0     0        1    430.477830              1       1
# ...                   ...   ...      ...           ...            ...     ...
# 68715                   0     1        2    856.555505              1       1
# 68716                   0     1        3   2304.147465              1       1
# 68717                   1     1        1  33362.792750              0       0
# 68718                   0     0        2   1173.708920              1       1
# 68719                   0     0        3   2439.532944              1       1
#
#        LONGITUDE   LATITUDE  POSTED_BY_Dealer  POSTED_BY_Owner  BHK_OR_RK_RK
# 0      21.262000  73.047700                 0                1             0
# 1      18.966114  73.148278                 1                0             0
# 2      22.592200  88.484911                 1                0             0
# 3      26.988300  75.584600                 1                0             0
# 4      22.700000  72.870000                 0                1             0
# ...          ...        ...               ...              ...           ...
# 68715  19.180000  72.963330                 1                0             0
# 68716  30.661104  76.746082                 1                0             0
# 68717  19.222101  72.988231                 1                0             0
# 68718  18.496670  73.941670                 1                0             0
# 68719  19.124896  72.893503                 1                0             0
#
# [68720 rows x 11 columns]

# %%
test_df.drop(columns=['POSTED_BY_Owner','RERA','UNDER_CONSTRUCTION','READY_TO_MOVE','RESALE','BHK_OR_RK_RK'], axis = 1, inplace=True)

# %%
predictions_new=pd.DataFrame(rf_random.predict(test_df))

# %%
predictions_new.to_csv('submission_rf.csv', index =False)

# %%
import pickle

# %%
# open a file, where you ant to store the data
file = open('rf_regression_model.pkl', 'wb')

pickle.dump(rf_random, file)

# %%
with open('rf_regression_model.pkl', 'rb') as file:
    rf_random= pickle.load(file)
